# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
list1 = [1,5,8,9,2,0,3,10,4,7]
list2 = [5,8,9,3,7,1,2,5]

# %%
ax = plt.axes()
ax.set_xlim([0,11])
ax.set_ylim([0,11])
ax.grid()
ax.set_xticks(range(1,11))
ax.set_yticks(range(1,11))
plt.plot(range(len(list1)), list1, 'r:v')
plt.plot(range(len(list2)), list2, 'm:v')
plt.legend(['List1', 'List2'], loc=9)
plt.show()

# %%
age = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
vitesse = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])

# %%
plt.scatter(age, vitesse)

# %%
x1 = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y1 = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])

x = np.array([2,2,8,1,15,8,12,9,7,3,11,4,7,14,12])
y = np.array([100,105,84,105,90,99,90,95,94,100,79,112,91,80,85])

# %%
plt.scatter(x1,y1)
plt.scatter(x,y)

# %%
x = np.array(["MPI", "RT", "IIA", "IMI"])
y = np.array([16.5, 15.8, 14.9, 13.7])
plt.bar(x,y)
plt.show()

# %%
y = np.array([35, 25, 25, 15])
mylabels = ["MPI", "RT", "IMI", "IIA"]
plt.pie(y, labels = mylabels)
plt.legend(title = "Four Fruits:", loc=2)
plt.show()

# %%
lst = ['GL', 'RT', 'IMI', 'MPI', 'IIA', 'CBA', 'CH', 'BIO']
data = {'Nom':['Ali', 'Mohamed', 'Salah', 'Fatma'],'Age':[20, 21, 19, 18]}
df1 = pd.DataFrame(lst)
print(df1)
df2 = pd.DataFrame(data)
print(df2)
# Out:
#      0
# 0   GL
# 1   RT
# 2  IMI
# 3  MPI
# 4  IIA
# 5  CBA
# 6   CH
# 7  BIO
#        Nom  Age
# 0      Ali   20
# 1  Mohamed   21
# 2    Salah   19
# 3    Fatma   18

# %%
data = {'Nom':['Ali', 'Salah', 'Fatma', 'Mohamed'],
'Age':[27, 24, 22, 32],
'Addresse':['Sfax', 'Tunis', 'Gabes', 'Sousse'],
'Filière':['MPI', 'RT', 'GL', 'IMI']}
df = pd.DataFrame(data)
print(df[['Nom', 'Filière']])
# Out:
#        Nom Filière
# 0      Ali     MPI
# 1    Salah      RT
# 2    Fatma      GL
# 3  Mohamed     IMI

# %%
data = pd.read_csv("./Atelier 1/Automobile.csv", index_col ="company")
first = data.loc["honda"]
second = data.loc["mazda"]
third = data["price"]
print(first, "\n\n\n", second, "\n\n\n", third)
# Out:
#          index body-style  wheel-base  length engine-type num-of-cylinders
# company
# honda       27      wagon        96.5   157.1         ohc             four  \
# honda       28      sedan        96.5   175.4         ohc             four
# honda       29      sedan        96.5   169.1         ohc             four
#
#          horsepower  average-mileage    price
# company
# honda            76               30   7295.0
# honda           101               24  12945.0
# honda           100               25  10345.0
#
#
#           index body-style  wheel-base  length engine-type num-of-cylinders
# company
# mazda       36  hatchback        93.1   159.1         ohc             four  \
# mazda       37  hatchback        93.1   159.1         ohc             four
# mazda       38  hatchback        93.1   159.1         ohc             four
# mazda       39  hatchback        95.3   169.0       rotor              two
# ...

# %%
data.head()
# Out:
#              index   body-style  wheel-base  length engine-type
# company
# alfa-romero      0  convertible        88.6   168.8        dohc  \
# alfa-romero      1  convertible        88.6   168.8        dohc
# alfa-romero      2    hatchback        94.5   171.2        ohcv
# audi             3        sedan        99.8   176.6         ohc
# audi             4        sedan        99.4   176.6         ohc
#
#             num-of-cylinders  horsepower  average-mileage    price
# company
# alfa-romero             four         111               21  13495.0
# alfa-romero             four         111               21  16500.0
# alfa-romero              six         154               19  16500.0
# audi                    four         102               24  13950.0
# audi                    five         115               18  17450.0

# %%
data.tail()
# Out:
#             index body-style  wheel-base  length engine-type num-of-cylinders
# company
# volkswagen     81      sedan        97.3   171.7         ohc             four  \
# volkswagen     82      sedan        97.3   171.7         ohc             four
# volkswagen     86      sedan        97.3   171.7         ohc             four
# volvo          87      sedan       104.3   188.8         ohc             four
# volvo          88      wagon       104.3   188.8         ohc             four
#
#             horsepower  average-mileage    price
# company
# volkswagen          85               27   7975.0
# volkswagen          52               37   7995.0
# volkswagen         100               26   9995.0
# volvo              114               23  12940.0
# volvo              114               23  13415.0

# %%
data.describe()
# Out:
#            index  wheel-base      length  horsepower  average-mileage
# count  61.000000   61.000000   61.000000   61.000000        61.000000  \
# mean   40.885246   98.481967  173.098361  107.852459        25.803279
# std    25.429706    6.679234   14.021846   53.524398         8.129821
# min     0.000000   88.400000  141.100000   48.000000        13.000000
# 25%    18.000000   94.500000  159.100000   68.000000        19.000000
# 50%    39.000000   96.300000  171.200000  100.000000        25.000000
# 75%    61.000000  101.200000  177.300000  123.000000        31.000000
# max    88.000000  120.900000  208.100000  288.000000        47.000000
#
#               price
# count     58.000000
# mean   15387.000000
# std    11320.259841
# min     5151.000000
# 25%     6808.500000
# 50%    11095.000000
# 75%    18120.500000
# max    45400.000000

# %%
SalesData = pd.read_csv("./Atelier 1/salesData.csv")

# %%
SalesData.head()
# Out:
#    month_number  facecream  facewash  toothpaste  bathingsoap  shampoo
# 0             1       2500      1500        5200         9200     1200  \
# 1             2       2630      1200        5100         6100     2100
# 2             3       2140      1340        4550         9550     3550
# 3             4       3400      1130        5870         8870     1870
# 4             5       3600      1740        4560         7760     1560
#
#    moisturizer  total_units  total_profit
# 0         1500        21100        211000
# 1         1200        18330        183300
# 2         1340        22470        224700
# 3         1130        22270        222700
# 4         1740        20960        209600

# %%
profit = SalesData["total_profit"]

# %%
ax = plt.axes()
ax.set_xlabel('month_number')
ax.set_ylabel('Profit in dollar')
plt.title('Company Sales data of last year')
plt.plot(range(1,13), profit,linewidth=3, color='r', linestyle=':', marker='o', markerfacecolor='k')
plt.legend(['Company Sales data of last year'], loc=4)

# %%
ax = plt.axes()
ax.set_xlabel('Month Number')
ax.set_ylabel('Sales Units in number')
ax.set_ylim([1000,18000])
for column in SalesData.columns[1:-2]:
    plt.plot(range(1,13), SalesData[column], marker='o', linewidth=2)
plt.legend(SalesData.columns[1:-2], loc=2)
plt.title('Sales Data')
# Out:
# Text(0.5, 1.0, 'Sales Data')

# %%
ax = plt.axes()
ax.set_xlabel('Month Number')
ax.set_ylabel('Number of units sold')
plt.scatter(range(1,13),SalesData["toothpaste"])
plt.legend(['toothpaste Sales Data'], loc=2)
plt.grid()
plt.title('Toothpaste Sales Data')
# Out:
# Text(0.5, 1.0, 'Toothpaste Sales Data')

# %%
profits = []
for column in SalesData.columns[1:-2]:
    profit = sum(SalesData[column])
    profits.append(profit)

plt.pie(profits, labels=SalesData.columns[1:-2], autopct='%1.1f%%')
plt.legend(SalesData.columns[1:-2], loc=4)
plt.title('Sales Data')
# Out:
# Text(0.5, 1.0, 'Sales Data')
